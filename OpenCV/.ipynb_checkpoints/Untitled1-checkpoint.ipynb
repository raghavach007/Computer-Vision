# %%
import cv2
img = cv2.imread('lalo.jpg')
print(img)
# Out:
# [[[212 172 153]
#   [212 172 153]
#   [212 172 153]
#   ...
#   [200 152 124]
#   [200 152 124]
#   [200 152 124]]
#
#  [[212 172 153]
#   [212 172 153]
#   [212 172 153]
#   ...
#   [200 152 124]
#   [200 152 124]
#   [200 152 124]]
#
#  [[212 172 153]
#   [212 172 153]
#   [212 172 153]
#   ...
#   [200 152 124]
#   [200 152 124]
#   [200 152 124]]
#
#  ...
#
#  [[144 203 243]
#   [131 190 230]
#   [115 174 214]
#   ...
#   [138 185 217]
#   [139 186 218]
#   [141 188 220]]
#
#  [[111 170 210]
#   [104 163 203]
#   [101 160 200]
#   ...
#   [144 191 223]
#   [145 192 224]
#   [146 193 225]]
#
#  [[136 197 237]
#   [122 183 223]
#   [116 175 215]
#   ...
#   [148 197 229]
#   [149 196 228]
#   [150 197 229]]]

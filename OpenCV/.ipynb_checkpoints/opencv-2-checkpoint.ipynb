# %%
import cv2
import matplotlib.pyplot as plt
file_path = r"/Users/raghavachakravarthula/OpenCv/lalo.jpg"
img = cv2.imread(file_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()
